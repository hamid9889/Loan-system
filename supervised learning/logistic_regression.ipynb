# %%
import numpy as np

# %%
class LogisticRegression:
    def __init__(self, learning_rate=0.1, n_iter=1000):
        self.lr = learning_rate
        self.n_iter = n_iter
        self.weights = None
        self.bias = None
        
    def _sigmoid(z):
        return 1 / (1 + np.exp(-z))
    
    def fit(self, X ,y):
        m, n = X.shape
        
        self.bias = 0
        self.weights = np.zeros(n)
        
        for i in range(self.n_iter):
            z =self.bias + np.dot(X, self.weights)
            y_pred = self._sigmoid(z)
            
            db = (1/m) * (y_pred - y)
            dw = (1/m) * np.dot(X.T, (y_pred - y))
            
            self.bias -= self.lr * db
            self.weights -= self.lr * dw
            
            
    def get_probabilities(self, X):
        z = self.bias + np.dot(X, self.weights)
        return self._sigmoid(z)
            
            
    def predict(self, X, threshold=0.5):
         probabilities = self.get_probabilities(X)
         y_preed = probabilities  >= threshold
         return y_pred_bool.astype(int)

# %%
X = np.array([[1, 2], [2, 3], [3, 4], [4, 5]])
y = np.array([0, 0, 1, 1])  

model = LogisticRegression()
model.fit(X, y)

y_pred = model.predict(X)
print("Predicted labels:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       2 y = np.array([0, 0, 1, 1])
#       4 model = LogisticRegression()
# ----> 5 model.fit(X, y)
#       7 y_pred = model.predict(X)
#       8 print("Predicted labels:", y_pred)
#
# Cell In[2], line 19, in LogisticRegression.fit(self, X, y)
#      17 for i in range(self.n_iter):
#      18     z =self.bias + np.dot(X, self.weights)
# ---> 19     y_pred = self._sigmoid(z)
#      21     db = (1/m) * (y_pred - y)
#      22     dw = (1/m) * np.dot(X.T, (y_pred - y))
#
# TypeError: LogisticRegression._sigmoid() takes 1 positional argument but 2 were given
